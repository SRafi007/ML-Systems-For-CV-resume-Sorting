# %%
import os
from sentence_transformers import SentenceTransformer, util
import torch
import pandas as pd
import fitz
import spacy
import re
import json

# %%
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    text = ""
    for page in doc:
        text +=page.get_text()
    return text

# %%
def extract_all_resumes_text(folder_path):
    resume_texts = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith(".pdf"):
            path = os.path.join(folder_path, file)
            text = extract_text_from_pdf(path)
            resume_texts.append(text)
            filenames.append(file)
    return filenames, resume_texts

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
#from utils.pdf_reader import extract_all_resumes_text
resume_names, resume_texts =  extract_all_resumes_text("../data/resumes/INFORMATION-TECHNOLOGY")
with open("../data/job_descs/job1.txt", "r") as f:
    job_description = f.read()


resume_embeddings = model.encode(resume_texts, convert_to_tensor=True)
job_embedding = model.encode(job_description, convert_to_tensor=True)

# Compute similarity
import torch
cos_scores = util.cos_sim(job_embedding, resume_embeddings)[0]

# %%
def extract_cgpa(text):
    match = re.search(r"CGPA[:\s]*([0-9]+\.[0-9]+)", text)
    if match:
        return float(match.group(1))
    return None

# %%
nlp = spacy.load("en_core_web_sm")

def extract_skills_from_text(text):
    doc = nlp(text.lower())
    skills = set()

    for chunk in doc.noun_chunks:
        if 1 <= len(chunk.text.split()) <= 3:
            skills.add(chunk.text.strip())

    return list(skills)

# Extract from job description
required_skills = extract_skills_from_text(job_description)

# Then proceed as before
def match_resume_skills(resume_text, required_skills):
    resume_text = resume_text.lower()
    matched = [skill for skill in required_skills if skill in resume_text]
    match_score = len(matched) / len(required_skills) if required_skills else 0
    return match_score, matched

# %%
def compute_final_score(similarity, cgpa=None, skills_matched=0):
    score = 0.6 * similarity
    score += 0.2 * (cgpa / 10 if cgpa else 0.5)
    score += 0.2 * skills_matched  # Out of 1.0
    return round(score, 4)

# Extract required skills dynamically from job description
required_skills = extract_skills_from_text(job_description)

results = []

for i, text in enumerate(resume_texts):
    sim = float(cos_scores[i])
    cgpa = extract_cgpa(text)

    # Skill matching
    skills_score, matched_skills = match_resume_skills(text, required_skills)

    # Final score
    score = compute_final_score(sim, cgpa, skills_score)
    results.append({
        "resume": resume_names[i],
        "score": score,
        "cgpa": cgpa,
        "similarity": sim,
        "skills_matched_count": len(matched_skills),
        "matched_skills": matched_skills
    })

# Sort by score
results = sorted(results, key=lambda x: x["score"], reverse=True)

# %%
results
# Out:
# [{'resume': '20674668.pdf',
#   'score': 0.4372,
#   'cgpa': None,
#   'similarity': 0.3952873647212982,
#   'skills_matched_count': 4,
#   'matched_skills': ['python', 'we', 'knowledge', 'experience']},
#  {'resume': '37242217.pdf',
#   'score': 0.3976,
#   'cgpa': None,
#   'similarity': 0.4127435088157654,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '11580408.pdf',
#   'score': 0.3831,
#   'cgpa': None,
#   'similarity': 0.3468329906463623,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '26480367.pdf',
#   'score': 0.382,
#   'cgpa': None,
#   'similarity': 0.303388774394989,
#   'skills_matched_count': 4,
#   'matched_skills': ['python', 'we', 'knowledge', 'experience']},
#  {'resume': '91635250.pdf',
#   'score': 0.3796,
#   'cgpa': None,
#   'similarity': 0.340921550989151,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '39413067.pdf',
#   'score': 0.3743,
#   'cgpa': None,
#   'similarity': 0.3321664333343506,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '83816738.pdf',
#   'score': 0.3722,
#   'cgpa': None,
#   'similarity': 0.32859206199645996,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '22450718.pdf',
#   'score': 0.3628,
#   'cgpa': None,
#   'similarity': 0.312943696975708,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '20237244.pdf',
#   'score': 0.3601,
#   'cgpa': None,
#   'similarity': 0.3501048982143402,
#   'skills_matched_count': 2,
#   'matched_skills': ['knowledge', 'experience']},
#  {'resume': '28897981.pdf',
#   'score': 0.3564,
#   'cgpa': None,
#   'similarity': 0.30236324667930603,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '15651486.pdf',
#   'score': 0.3561,
#   'cgpa': None,
#   'similarity': 0.34343254566192627,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '25207620.pdf',
#   'score': 0.3555,
#   'cgpa': None,
#   'similarity': 0.3007541298866272,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '10839851.pdf',
#   'score': 0.3517,
#   'cgpa': None,
#   'similarity': 0.33615124225616455,
#   'skills_matched_count': 2,
#   'matched_skills': ['knowledge', 'experience']},
#  {'resume': '13405733.pdf',
#   'score': 0.3491,
#   'cgpa': None,
#   'similarity': 0.29011568427085876,
#   'skills_matched_count': 3,
#   'matched_skills': ['python', 'we', 'experience']},
#  {'resume': '17641670.pdf',
#   'score': 0.3482,
#   'cgpa': None,
#   'similarity': 0.2886843681335449,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '12635195.pdf',
#   'score': 0.3469,
#   'cgpa': None,
#   'similarity': 0.286440372467041,
#   'skills_matched_count': 3,
#   'matched_skills': ['python', 'we', 'experience']},
#  {'resume': '16186411.pdf',
#   'score': 0.3447,
#   'cgpa': None,
#   'similarity': 0.32449841499328613,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '26746496.pdf',
#   'score': 0.3406,
#   'cgpa': None,
#   'similarity': 0.31762877106666565,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '46260230.pdf',
#   'score': 0.3399,
#   'cgpa': None,
#   'similarity': 0.27477753162384033,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '24020470.pdf',
#   'score': 0.3382,
#   'cgpa': None,
#   'similarity': 0.27201953530311584,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '20408458.pdf',
#   'score': 0.3358,
#   'cgpa': None,
#   'similarity': 0.3095925748348236,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '19201175.pdf',
#   'score': 0.3354,
#   'cgpa': None,
#   'similarity': 0.26730501651763916,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '37764298.pdf',
#   'score': 0.334,
#   'cgpa': None,
#   'similarity': 0.3066922724246979,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '40018190.pdf',
#   'score': 0.3329,
#   'cgpa': None,
#   'similarity': 0.30477938055992126,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '52618188.pdf',
#   'score': 0.33,
#   'cgpa': None,
#   'similarity': 0.2583329677581787,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '10840430.pdf',
#   'score': 0.3285,
#   'cgpa': None,
#   'similarity': 0.2975153625011444,
#   'skills_matched_count': 2,
#   'matched_skills': ['knowledge', 'experience']},
#  {'resume': '90867631.pdf',
#   'score': 0.3258,
#   'cgpa': None,
#   'similarity': 0.25133025646209717,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '27770859.pdf',
#   'score': 0.324,
#   'cgpa': None,
#   'similarity': 0.24834483861923218,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '51639418.pdf',
#   'score': 0.324,
#   'cgpa': None,
#   'similarity': 0.2900145351886749,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '11957080.pdf',
#   'score': 0.322,
#   'cgpa': None,
#   'similarity': 0.24492201209068298,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '20001721.pdf',
#   'score': 0.3208,
#   'cgpa': None,
#   'similarity': 0.28468388319015503,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '17111768.pdf',
#   'score': 0.3204,
#   'cgpa': None,
#   'similarity': 0.2423977255821228,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '10265057.pdf',
#   'score': 0.3195,
#   'cgpa': None,
#   'similarity': 0.2409076690673828,
#   'skills_matched_count': 3,
#   'matched_skills': ['python', 'we', 'experience']},
#  {'resume': '29975124.pdf',
#   'score': 0.3177,
#   'cgpa': None,
#   'similarity': 0.27948009967803955,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '79541391.pdf',
#   'score': 0.3174,
#   'cgpa': None,
#   'similarity': 0.2790273427963257,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '25905275.pdf',
#   'score': 0.3173,
#   'cgpa': None,
#   'similarity': 0.2371634542942047,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '27372171.pdf',
#   'score': 0.3169,
#   'cgpa': None,
#   'similarity': 0.2364514172077179,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '51363762.pdf',
#   'score': 0.3153,
#   'cgpa': None,
#   'similarity': 0.2338017076253891,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '18187364.pdf',
#   'score': 0.3137,
#   'cgpa': None,
#   'similarity': 0.23123040795326233,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '18301617.pdf',
#   'score': 0.3117,
#   'cgpa': None,
#   'similarity': 0.26945751905441284,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '52246737.pdf',
#   'score': 0.3112,
#   'cgpa': None,
#   'similarity': 0.26859158277511597,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '24913648.pdf',
#   'score': 0.3104,
#   'cgpa': None,
#   'similarity': 0.26736998558044434,
#   'skills_matched_count': 2,
#   'matched_skills': ['knowledge', 'experience']},
#  {'resume': '28126340.pdf',
#   'score': 0.3102,
#   'cgpa': None,
#   'similarity': 0.2252841591835022,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '22776912.pdf',
#   'score': 0.31,
#   'cgpa': None,
#   'similarity': 0.2250378131866455,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '10641230.pdf',
#   'score': 0.3072,
#   'cgpa': None,
#   'similarity': 0.2619849443435669,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '11584809.pdf',
#   'score': 0.3064,
#   'cgpa': None,
#   'similarity': 0.2190796285867691,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '36434348.pdf',
#   'score': 0.3058,
#   'cgpa': None,
#   'similarity': 0.25958943367004395,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '91121135.pdf',
#   'score': 0.3036,
#   'cgpa': None,
#   'similarity': 0.2143406867980957,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '13836471.pdf',
#   'score': 0.3031,
#   'cgpa': None,
#   'similarity': 0.21349358558654785,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '13477922.pdf',
#   'score': 0.3024,
#   'cgpa': None,
#   'similarity': 0.25402507185935974,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '57002858.pdf',
#   'score': 0.3016,
#   'cgpa': None,
#   'similarity': 0.2109266072511673,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '25990239.pdf',
#   'score': 0.2999,
#   'cgpa': None,
#   'similarity': 0.2497905194759369,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '15297298.pdf',
#   'score': 0.2988,
#   'cgpa': None,
#   'similarity': 0.2063927948474884,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '18067556.pdf',
#   'score': 0.2985,
#   'cgpa': None,
#   'similarity': 0.16410061717033386,
#   'skills_matched_count': 4,
#   'matched_skills': ['python', 'we', 'knowledge', 'experience']},
#  {'resume': '21283365.pdf',
#   'score': 0.2978,
#   'cgpa': None,
#   'similarity': 0.24626585841178894,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '24889109.pdf',
#   'score': 0.2968,
#   'cgpa': None,
#   'similarity': 0.20296230912208557,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '10089434.pdf',
#   'score': 0.2953,
#   'cgpa': None,
#   'similarity': 0.2005777359008789,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '17987433.pdf',
#   'score': 0.2918,
#   'cgpa': None,
#   'similarity': 0.19463932514190674,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '91697974.pdf',
#   'score': 0.2894,
#   'cgpa': None,
#   'similarity': 0.19066128134727478,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '31111279.pdf',
#   'score': 0.289,
#   'cgpa': None,
#   'similarity': 0.23161542415618896,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '20879311.pdf',
#   'score': 0.2885,
#   'cgpa': None,
#   'similarity': 0.2308516800403595,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '10247517.pdf',
#   'score': 0.2873,
#   'cgpa': None,
#   'similarity': 0.22882753610610962,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '17688766.pdf',
#   'score': 0.2872,
#   'cgpa': None,
#   'similarity': 0.22863510251045227,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '26768723.pdf',
#   'score': 0.2863,
#   'cgpa': None,
#   'similarity': 0.18545980751514435,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '31243710.pdf',
#   'score': 0.2857,
#   'cgpa': None,
#   'similarity': 0.1844199299812317,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '28035460.pdf',
#   'score': 0.2828,
#   'cgpa': None,
#   'similarity': 0.2213859260082245,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '29051656.pdf',
#   'score': 0.2819,
#   'cgpa': None,
#   'similarity': 0.21975961327552795,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '20824105.pdf',
#   'score': 0.28,
#   'cgpa': None,
#   'similarity': 0.17492958903312683,
#   'skills_matched_count': 3,
#   'matched_skills': ['python', 'we', 'experience']},
#  {'resume': '48037995.pdf',
#   'score': 0.2799,
#   'cgpa': None,
#   'similarity': 0.17488476634025574,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '19850482.pdf',
#   'score': 0.279,
#   'cgpa': None,
#   'similarity': 0.21499201655387878,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '20024870.pdf',
#   'score': 0.2787,
#   'cgpa': None,
#   'similarity': 0.17290924489498138,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '19796840.pdf',
#   'score': 0.2763,
#   'cgpa': None,
#   'similarity': 0.1687745749950409,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '12763627.pdf',
#   'score': 0.2756,
#   'cgpa': None,
#   'similarity': 0.2093532681465149,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '25857360.pdf',
#   'score': 0.2733,
#   'cgpa': None,
#   'similarity': 0.16383379697799683,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '33241454.pdf',
#   'score': 0.2733,
#   'cgpa': None,
#   'similarity': 0.20545393228530884,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '16533554.pdf',
#   'score': 0.2731,
#   'cgpa': None,
#   'similarity': 0.20515789091587067,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '18752129.pdf',
#   'score': 0.2724,
#   'cgpa': None,
#   'similarity': 0.16238585114479065,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '27485716.pdf',
#   'score': 0.2696,
#   'cgpa': None,
#   'similarity': 0.15758484601974487,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '89413122.pdf',
#   'score': 0.2692,
#   'cgpa': None,
#   'similarity': 0.19864600896835327,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '36856210.pdf',
#   'score': 0.269,
#   'cgpa': None,
#   'similarity': 0.15671177208423615,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '68460556.pdf',
#   'score': 0.2672,
#   'cgpa': None,
#   'similarity': 0.19533169269561768,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '16899268.pdf',
#   'score': 0.2669,
#   'cgpa': None,
#   'similarity': 0.19483210146427155,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '81761658.pdf',
#   'score': 0.2663,
#   'cgpa': None,
#   'similarity': 0.1939128339290619,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '32959732.pdf',
#   'score': 0.2636,
#   'cgpa': None,
#   'similarity': 0.14767660200595856,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '24038620.pdf',
#   'score': 0.2601,
#   'cgpa': None,
#   'similarity': 0.14179196953773499,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '28697203.pdf',
#   'score': 0.2595,
#   'cgpa': None,
#   'similarity': 0.18256494402885437,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '18176523.pdf',
#   'score': 0.2589,
#   'cgpa': None,
#   'similarity': 0.18155603110790253,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '64017585.pdf',
#   'score': 0.2587,
#   'cgpa': None,
#   'similarity': 0.18111452460289001,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '23666211.pdf',
#   'score': 0.2571,
#   'cgpa': None,
#   'similarity': 0.22020988166332245,
#   'skills_matched_count': 1,
#   'matched_skills': ['experience']},
#  {'resume': '24083609.pdf',
#   'score': 0.256,
#   'cgpa': None,
#   'similarity': 0.2182522714138031,
#   'skills_matched_count': 1,
#   'matched_skills': ['experience']},
#  {'resume': '13385306.pdf',
#   'score': 0.2546,
#   'cgpa': None,
#   'similarity': 0.1742573082447052,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '25959103.pdf',
#   'score': 0.2535,
#   'cgpa': None,
#   'similarity': 0.21417631208896637,
#   'skills_matched_count': 1,
#   'matched_skills': ['experience']},
#  {'resume': '23864648.pdf',
#   'score': 0.2521,
#   'cgpa': None,
#   'similarity': 0.12844932079315186,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '66832845.pdf',
#   'score': 0.2492,
#   'cgpa': None,
#   'similarity': 0.20694264769554138,
#   'skills_matched_count': 1,
#   'matched_skills': ['we']},
#  {'resume': '92069209.pdf',
#   'score': 0.2475,
#   'cgpa': None,
#   'similarity': 0.162553071975708,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '28672970.pdf',
#   'score': 0.2455,
#   'cgpa': None,
#   'similarity': 0.15908637642860413,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '30223363.pdf',
#   'score': 0.2447,
#   'cgpa': None,
#   'similarity': 0.15779730677604675,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '23527321.pdf',
#   'score': 0.2443,
#   'cgpa': None,
#   'similarity': 0.15710760653018951,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '12045067.pdf',
#   'score': 0.2439,
#   'cgpa': None,
#   'similarity': 0.15657803416252136,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '27058381.pdf',
#   'score': 0.2435,
#   'cgpa': None,
#   'similarity': 0.1141505092382431,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '14789139.pdf',
#   'score': 0.2394,
#   'cgpa': None,
#   'similarity': 0.14907661080360413,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '29075857.pdf',
#   'score': 0.2389,
#   'cgpa': None,
#   'similarity': 0.10654342919588089,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '15118506.pdf',
#   'score': 0.2382,
#   'cgpa': None,
#   'similarity': 0.14701418578624725,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '26801767.pdf',
#   'score': 0.236,
#   'cgpa': None,
#   'similarity': 0.14329025149345398,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '70089206.pdf',
#   'score': 0.2352,
#   'cgpa': None,
#   'similarity': 0.14200802147388458,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '10553553.pdf',
#   'score': 0.2294,
#   'cgpa': None,
#   'similarity': 0.13236576318740845,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '15802627.pdf',
#   'score': 0.2268,
#   'cgpa': None,
#   'similarity': 0.08626659959554672,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '24230851.pdf',
#   'score': 0.222,
#   'cgpa': None,
#   'similarity': 0.11995954811573029,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '35325329.pdf',
#   'score': 0.2191,
#   'cgpa': None,
#   'similarity': 0.11518875509500504,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '15791766.pdf',
#   'score': 0.2171,
#   'cgpa': None,
#   'similarity': 0.11176279187202454,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '33381211.pdf',
#   'score': 0.2162,
#   'cgpa': None,
#   'similarity': 0.11032256484031677,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '38753827.pdf',
#   'score': 0.2155,
#   'cgpa': None,
#   'similarity': 0.10909174382686615,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '27536013.pdf',
#   'score': 0.2125,
#   'cgpa': None,
#   'similarity': 0.06252939999103546,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '21780877.pdf',
#   'score': 0.2122,
#   'cgpa': None,
#   'similarity': 0.10359208285808563,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '18159866.pdf',
#   'score': 0.2107,
#   'cgpa': None,
#   'similarity': 0.05944572761654854,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']},
#  {'resume': '17681064.pdf',
#   'score': 0.1957,
#   'cgpa': None,
#   'similarity': 0.07609522342681885,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '39718499.pdf',
#   'score': 0.1946,
#   'cgpa': None,
#   'similarity': 0.07437612116336823,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '27295996.pdf',
#   'score': 0.1813,
#   'cgpa': None,
#   'similarity': 0.09380272775888443,
#   'skills_matched_count': 1,
#   'matched_skills': ['experience']},
#  {'resume': '41344156.pdf',
#   'score': 0.1741,
#   'cgpa': None,
#   'similarity': 0.04020829498767853,
#   'skills_matched_count': 2,
#   'matched_skills': ['we', 'experience']},
#  {'resume': '12334140.pdf',
#   'score': 0.1559,
#   'cgpa': None,
#   'similarity': -0.031815022230148315,
#   'skills_matched_count': 3,
#   'matched_skills': ['we', 'knowledge', 'experience']}]

# %%
df = pd.DataFrame(results)
df
# Out:
#            resume   score  cgpa  similarity  skills_matched_count  \
# 0    20674668.pdf  0.4372  None    0.395287                     4
# 1    37242217.pdf  0.3976  None    0.412744                     2
# 2    11580408.pdf  0.3831  None    0.346833                     3
# 3    26480367.pdf  0.3820  None    0.303389                     4
# 4    91635250.pdf  0.3796  None    0.340922                     3
# ..            ...     ...   ...         ...                   ...
# 115  17681064.pdf  0.1957  None    0.076095                     2
# 116  39718499.pdf  0.1946  None    0.074376                     2
# 117  27295996.pdf  0.1813  None    0.093803                     1
# 118  41344156.pdf  0.1741  None    0.040208                     2
# 119  12334140.pdf  0.1559  None   -0.031815                     3
#
#                           matched_skills
# 0    [python, we, knowledge, experience]
# 1                       [we, experience]
# 2            [we, knowledge, experience]
# 3    [python, we, knowledge, experience]
# 4            [we, knowledge, experience]
# ..                                   ...
# 115                     [we, experience]
# 116                     [we, experience]
# 117                         [experience]
# 118                     [we, experience]
# 119          [we, knowledge, experience]
#
# [120 rows x 6 columns]
